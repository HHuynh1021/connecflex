# %%
from dataclasses import replace

import py
import ulid

def custom_id(length=25):
    uid = ulid.new().str().lower()
    return uid[:length]
string = custom_id()
print(string)
# Out:
# 01kcm2vzd0tvzd076q9sdn6hf

# %%
import ulid
def custom_id(length=25):
    uid = ulid.new()
    uid = uid.str()
    return uid[:length]
string = custom_id().lower()
print(string)
# Out:
# 01kcm385s2kpmw4sqbzwezw06
